# %%
import os

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  '720p_240fps_1',
#  '720p_240fps_2',
#  '720p_240fps_3',
#  '720p_240fps_5',
#  '720p_240fps_6',
#  'C0036',
#  'C0041',
#  'GOPR9633',
#  'GOPR9636',
#  'GOPR9641',
#  'GOPR9642',
#  'GOPR9643',
#  'GOPR9645',
#  'GOPR9648',
#  'GOPR9652',
#  'IMG_0001',
#  'IMG_0003',
#  'IMG_0004',
#  'IMG_0005',
#  'IMG_0008',
#  'IMG_0009',
#  'IMG_0010',
#  'IMG_0011',
#  'IMG_0012',
#  'IMG_0013',
#  'IMG_0014',
#  'IMG_0015',
#  'IMG_0017',
#  'IMG_0019',
#  'IMG_0021',
#  'IMG_0022',
#  'IMG_0023',
#  'IMG_0024',
#  'IMG_0025',
#  'IMG_0026',
#  'IMG_0028',
#  'IMG_0029',
#  'IMG_0030',
#  'IMG_0031',
#  'IMG_0032',
#  'IMG_0033',
#  'IMG_0034',
#  'IMG_0035',
#  'IMG_0036',
#  'IMG_0037',
#  'IMG_0038',
#  'IMG_0039',
#  'IMG_0040',
#  'IMG_0041',
#  'IMG_0042',
#  'IMG_0043',
#  'IMG_0044',
#  'IMG_0045',
#  'IMG_0046',
#  'IMG_0047',
#  'IMG_0049',
#  'IMG_0051',
#  'IMG_0053',
#  'IMG_0054',
#  'IMG_0055',
#  'IMG_0056',
#  'IMG_0058',
# ...

# %%
dirs = [
 '720p_240fps_1',
 '720p_240fps_2',
 '720p_240fps_3',
 '720p_240fps_5',
 '720p_240fps_6',
 'C0036',
 'C0041',
 'GOPR9633',
 'GOPR9636',
 'GOPR9641',
 'GOPR9642',
 'GOPR9643',
 'GOPR9645',
 'GOPR9648',
 'GOPR9652',
 'IMG_0001',
 'IMG_0003',
 'IMG_0004',
 'IMG_0005',
 'IMG_0008',
 'IMG_0009',
 'IMG_0010',
 'IMG_0011',
 'IMG_0012',
 'IMG_0013',
 'IMG_0014',
 'IMG_0015',
 'IMG_0017',
 'IMG_0019',
 'IMG_0021',
 'IMG_0022',
 'IMG_0023',
 'IMG_0024',
 'IMG_0025',
 'IMG_0026',
 'IMG_0028',
 'IMG_0029',
 'IMG_0030',
 'IMG_0031',
 'IMG_0032',
 'IMG_0033',
 'IMG_0034',
 'IMG_0035',
 'IMG_0036',
 'IMG_0037',
 'IMG_0038',
 'IMG_0039',
 'IMG_0040',
 'IMG_0041',
 'IMG_0042',
 'IMG_0043',
 'IMG_0044',
 'IMG_0045',
 'IMG_0046',
 'IMG_0047',
 'IMG_0049',
 'IMG_0051',
 'IMG_0053',
 'IMG_0054',
 'IMG_0055',
 'IMG_0056',
 'IMG_0058',
 'IMG_0150',
 'IMG_0151',
 'IMG_0153',
 'IMG_0155',
 'IMG_0164',
 'IMG_0173',
 'IMG_0180',
 'IMG_0183',
 'IMG_0200']

# %%
dirs
# Out:
# ['720p_240fps_1',
#  '720p_240fps_2',
#  '720p_240fps_3',
#  '720p_240fps_5',
#  '720p_240fps_6',
#  'C0036',
#  'C0041',
#  'GOPR9633',
#  'GOPR9636',
#  'GOPR9641',
#  'GOPR9642',
#  'GOPR9643',
#  'GOPR9645',
#  'GOPR9648',
#  'GOPR9652',
#  'IMG_0001',
#  'IMG_0003',
#  'IMG_0004',
#  'IMG_0005',
#  'IMG_0008',
#  'IMG_0009',
#  'IMG_0010',
#  'IMG_0011',
#  'IMG_0012',
#  'IMG_0013',
#  'IMG_0014',
#  'IMG_0015',
#  'IMG_0017',
#  'IMG_0019',
#  'IMG_0021',
#  'IMG_0022',
#  'IMG_0023',
#  'IMG_0024',
#  'IMG_0025',
#  'IMG_0026',
#  'IMG_0028',
#  'IMG_0029',
#  'IMG_0030',
#  'IMG_0031',
#  'IMG_0032',
#  'IMG_0033',
#  'IMG_0034',
#  'IMG_0035',
#  'IMG_0036',
#  'IMG_0037',
#  'IMG_0038',
#  'IMG_0039',
#  'IMG_0040',
#  'IMG_0041',
#  'IMG_0042',
#  'IMG_0043',
#  'IMG_0044',
#  'IMG_0045',
#  'IMG_0046',
#  'IMG_0047',
#  'IMG_0049',
#  'IMG_0051',
#  'IMG_0053',
#  'IMG_0054',
#  'IMG_0055',
#  'IMG_0056',
#  'IMG_0058',
#  'IMG_0150',
#  'IMG_0151',
#  'IMG_0153',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['dirname'] = dirs

# %%
counter = [
    100,
    100,
    100,
    100,
    100,
    63,
    229,
    35,
    48,
    137,
    83,
    97,
    65,
    88,
    71,
    100,
    100,
    100,
    100,
    100,
    41,
    100,
    100,
    100,
    100,
    100,
    
    
]
# Out:
#           dirname
# 0   720p_240fps_1
# 1   720p_240fps_2
# 2   720p_240fps_3
# 3   720p_240fps_5
# 4   720p_240fps_6
# ..            ...
# 66       IMG_0164
# 67       IMG_0173
# 68       IMG_0180
# 69       IMG_0183
# 70       IMG_0200
#
# [71 rows x 1 columns]

# %%
import os
def getNum(dir):
    list = os.listdir(dir) 
    number_files = len(list)
    return number_files

# %%
nums
for x in dirs:
    print(x, getNum(x+'/GT'))
# Out:
# 720p_240fps_1 100
# 720p_240fps_2 100
# 720p_240fps_3 100
# 720p_240fps_5 100
# 720p_240fps_6 100
# C0036 63
# C0041 229
# GOPR9633 35
# GOPR9636 48
# GOPR9641 137
# GOPR9642 83
# GOPR9643 97
# GOPR9645 65
# GOPR9648 88
# GOPR9652 71
# IMG_0001 100
# IMG_0003 100
# IMG_0004 100
# IMG_0005 100
# IMG_0008 100
# IMG_0009 41
# IMG_0010 100
# IMG_0011 100
# IMG_0012 100
# IMG_0013 100
# IMG_0014 100
# IMG_0015 100
# IMG_0017 100
# IMG_0019 100
# IMG_0021 100
# IMG_0022 100
# IMG_0023 100
# IMG_0024 100
# IMG_0025 100
# IMG_0026 100
# IMG_0028 100
# IMG_0029 100
# IMG_0030 100
# IMG_0031 100
# IMG_0032 100
# IMG_0033 100
# IMG_0034 100
# IMG_0035 100
# IMG_0036 100
# IMG_0037 100
# IMG_0038 100
# IMG_0039 100
# IMG_0040 100
# IMG_0041 100
# IMG_0042 100
# IMG_0043 100
# IMG_0044 100
# IMG_0045 61
# IMG_0046 100
# IMG_0047 100
# IMG_0049 100
# IMG_0051 100
# IMG_0053 100
# IMG_0054 100
# IMG_0055 100
# IMG_0056 100
# IMG_0058 100
# IMG_0150 50
# IMG_0151 60
# IMG_0153 120
# IMG_0155 78
# ...
